# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests
r = requests.get('https://udn.com/news/story/6811/4468361?from=udn_ch2_menu_v2_main_cate')
response = r.text

response
# Out:
# '<!--getArticle 0.0086 --><!--hottest_news 0.0092 --><!--getReporter 0.0109 --><!--extend_news 0.0017 --><!-- enter if --><!--related_news 0.0577 --><!--content 0.3481 --><!--ad_1 0.3133 --><!--ad 0.5171 --><!--view_type 0.0000 --><!--meta 0.2217 --><!--family_bar 0.0007 --><!--family_bar sub  --><!--breaking_news 0.0008 --><!--top 0.0140 --><!--bottom 0.0156 --><!--nav 0.0000 --><!--code 1.1248 --><!DOCTYPE html>\n<html lang="zh-TW">\n<head>\n<!--\n  <meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <meta http-equiv="X-UA-Compatible" content="ie=edge">\n  <meta name="description" content="網頁敘述">\n  <meta name="theme-color" content="#f46c00" />\n-->\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta http-equiv="content-language" content="zh-Hant-TW">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n<!-- favicon -->\n<link rel="icon" href="/static/img/icons/icon-128x128.png" sizes="128x128">\n<link rel="icon" href="/static/img/icons/icon-192x192.png" sizes="192x192">\n<link rel="icon" type="image/x-icon" href="/static/img/favicon.ico" />\n<meta name="twitter:card" content="summary" />\n<!-- for Facebook -->\n<meta property="og:title" content="股神大賣兩檔航空股 | 聯合新聞網：最懂你的新聞網站"/>\n<meta property="og:type" content="article"/>\n<meta property="og:url" content="https://udn.com/news/story/6811/4468361"/>\n<meta property="og:image" content="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2020/04/05/2/7690167.jpg&s=Y&x=0&y=0&sw=1279&sh=832&exp=3600"/>\n<meta property="og:image:width" content="1000"/>\n<meta property="og:image:height" content="1000"/>\n<meta property="og:site_name" content="聯合新聞網"/>\n<meta property="og:description" content="「股神」巴菲特的波克夏公司3日表示，4月1-2日出售了達美與西南兩家航空公司的部分持股，更加凸顯新冠肺炎疫情已經讓航空業陷入史無前例的危機。"/>\n<meta property="fb:admins" content="100002847892748" />\n<meta property="fb:app_id" content="350231215126101" />\n<meta property="fb:pages" content="241284961029,219315794887869,163253543730991,362512194085320,413437005485686,578214755657993" />\n<meta property="article:author" content="https://www.facebook.com/myudn/" />\n<meta property="article:publisher" content="https://www.facebook.com/myudn/" />\n\n<!-- for Google -->\n<meta name="description" content="「股神」巴菲特的波克夏公司3日表示，4月1-2日出售了達美與西南兩家航空公司的部分持股，更加凸顯新冠肺炎疫情已經讓航空業陷入史無前例的危機。" />\n<meta name="author" content="聯合新聞網" />\n<meta name="copyright" content="聯合新聞網" />\n<meta name="application-name" content="聯合新聞網" />\n<meta name="google-site-verification" content="zxOxo5I1xPvrdU_l5_sX9kZ8v0SiUC18mtRszIAsHqk" />\n<!-- for follow & save -->\n<meta name="date.available" content="2020-04-05 02:11:07">\n<!-- for idle page -->\n<meta name="channel_id" content="2">\n<meta name="cate_id" content="7225">\n<meta name="sub_id" content="6811">\n<meta name="art_id" content="4468361">\n\n<!-- for udn track -->\n<meta name="list-image" content="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2020/04/05/2/7690167.jpg&s=Y&x=0&y=0&sw=1279&sh=832&exp=3600" /> \n\n\n\n<meta name="news_keywords" content="波克夏,巴菲特,新冠肺炎">\n\n<!--<link href="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2020/04/05/2/7690167.jpg&s=Y&x=0&y=0&sw=1279&sh=832&exp=3600" rel="image_src" type="image/jpeg">-->\n<meta name="URL" content="https://udn.com/news/story/6811/4468361"/>\n<meta name="date" content="2020-04-05 02:11:07">\n\n\n<link rel="canonical" href="https://udn.com/news/story/6811/4468361"/>\n\n<link rel="amphtml" href="https://udn.com/news/amp/story/6811/4468361">\n\n\n<!-- 57×57px -->\n<link rel="apple-touch-icon" href="https://uc.udn.com.tw/upf/news/2017/images/icon_mobile_57x57.png">\n<!-- 72×72px ipad-->\n<link rel="apple-touch-icon" sizes="72×72" href="https://uc.udn.com.tw/upf/news/2017/images/icon_mobile_72x72.png">\n<!-- 114×114px iphone4-->\n<link rel="apple-touch-icon" sizes=" ...

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
"""
Your Code Here
"""
# Out:
# '\nYour Code Here\n'

# %%
headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:74.0) Gecko/20100101 Firefox/74.0',
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
'Accept-Language': 'zh-TW,zh;q=0.8,en-US;q=0.5,en;q=0.3',
'Accept-Encoding': 'gzip, deflate, br',
}

# %%
r = requests.get('https://udn.com/news/story/6811/4468361?from=udn_ch2_menu_v2_main_cate', headers=headers)
response = r.text

response
# Out:
# '<!--getArticle 0.0082 --><!--hottest_news 0.0086 --><!--getReporter 0.0084 --><!--extend_news 0.0044 --><!-- enter if --><!--related_news 0.0675 --><!--content 0.3734 --><!--ad_1 0.1268 --><!--ad 0.3218 --><!--view_type 0.0000 --><!--meta 0.0105 --><!--family_bar 0.0007 --><!--family_bar sub  --><!--breaking_news 0.0068 --><!--top 0.0129 --><!--bottom 0.0027 --><!--nav 0.0000 --><!--code 0.7300 --><!DOCTYPE html>\n<html lang="zh-TW">\n<head>\n<!--\n  <meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <meta http-equiv="X-UA-Compatible" content="ie=edge">\n  <meta name="description" content="網頁敘述">\n  <meta name="theme-color" content="#f46c00" />\n-->\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta http-equiv="content-language" content="zh-Hant-TW">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n<!-- favicon -->\n<link rel="icon" href="/static/img/icons/icon-128x128.png" sizes="128x128">\n<link rel="icon" href="/static/img/icons/icon-192x192.png" sizes="192x192">\n<link rel="icon" type="image/x-icon" href="/static/img/favicon.ico" />\n<meta name="twitter:card" content="summary" />\n<!-- for Facebook -->\n<meta property="og:title" content="股神大賣兩檔航空股 | 聯合新聞網：最懂你的新聞網站"/>\n<meta property="og:type" content="article"/>\n<meta property="og:url" content="https://udn.com/news/story/6811/4468361"/>\n<meta property="og:image" content="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2020/04/05/2/7690167.jpg&s=Y&x=0&y=0&sw=1279&sh=832&exp=3600"/>\n<meta property="og:image:width" content="1000"/>\n<meta property="og:image:height" content="1000"/>\n<meta property="og:site_name" content="聯合新聞網"/>\n<meta property="og:description" content="「股神」巴菲特的波克夏公司3日表示，4月1-2日出售了達美與西南兩家航空公司的部分持股，更加凸顯新冠肺炎疫情已經讓航空業陷入史無前例的危機。"/>\n<meta property="fb:admins" content="100002847892748" />\n<meta property="fb:app_id" content="350231215126101" />\n<meta property="fb:pages" content="241284961029,219315794887869,163253543730991,362512194085320,413437005485686,578214755657993" />\n<meta property="article:author" content="https://www.facebook.com/myudn/" />\n<meta property="article:publisher" content="https://www.facebook.com/myudn/" />\n\n<!-- for Google -->\n<meta name="description" content="「股神」巴菲特的波克夏公司3日表示，4月1-2日出售了達美與西南兩家航空公司的部分持股，更加凸顯新冠肺炎疫情已經讓航空業陷入史無前例的危機。" />\n<meta name="author" content="聯合新聞網" />\n<meta name="copyright" content="聯合新聞網" />\n<meta name="application-name" content="聯合新聞網" />\n<meta name="google-site-verification" content="zxOxo5I1xPvrdU_l5_sX9kZ8v0SiUC18mtRszIAsHqk" />\n<!-- for follow & save -->\n<meta name="date.available" content="2020-04-05 02:11:07">\n<!-- for idle page -->\n<meta name="channel_id" content="2">\n<meta name="cate_id" content="7225">\n<meta name="sub_id" content="6811">\n<meta name="art_id" content="4468361">\n\n<!-- for udn track -->\n<meta name="list-image" content="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2020/04/05/2/7690167.jpg&s=Y&x=0&y=0&sw=1279&sh=832&exp=3600" /> \n\n\n\n<meta name="news_keywords" content="波克夏,巴菲特,新冠肺炎">\n\n<!--<link href="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2020/04/05/2/7690167.jpg&s=Y&x=0&y=0&sw=1279&sh=832&exp=3600" rel="image_src" type="image/jpeg">-->\n<meta name="URL" content="https://udn.com/news/story/6811/4468361"/>\n<meta name="date" content="2020-04-05 02:11:07">\n\n\n<link rel="canonical" href="https://udn.com/news/story/6811/4468361"/>\n\n<link rel="amphtml" href="https://udn.com/news/amp/story/6811/4468361">\n\n\n<!-- 57×57px -->\n<link rel="apple-touch-icon" href="https://uc.udn.com.tw/upf/news/2017/images/icon_mobile_57x57.png">\n<!-- 72×72px ipad-->\n<link rel="apple-touch-icon" sizes="72×72" href="https://uc.udn.com.tw/upf/news/2017/images/icon_mobile_72x72.png">\n<!-- 114×114px iphone4-->\n<link rel="apple-touch-icon" sizes=" ...
